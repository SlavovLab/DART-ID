# %%
import numpy as np
import pandas as pd
import argparse
import sys
import pickle
import pystan
import time
import os
import logging
from hashlib import md5
import matplotlib.pyplot as plt
from scipy.stats import laplace
from sklearn import linear_model

# %%
df = pd.read_csv("./../dat/evidence_elite_c.txt", sep="\t")

# %%
dff = df[-(df["exclude"])]
dff = dff.reset_index(drop=True)
dff
# Out:
#                sequence                                         raw_file  \
# 0         _AAAAAAALQAK_   1608329A_NC_set#29B_180min_200NL_60C+N=3_250ms
# 1         _AAAAAAALQAK_              160818A_NC_set#26C_180min_200NL_60C
# 2         _AAAAAAALQAK_              160818A_NC_set#26C_180min_200NL_60C
# 3         _AAAAAAALQAK_                  160629AEL160624PMRSAM00092_18B1
# 4         _AAAAAAALQAK_                  160629AEL160624PMRSAM00092_18A2
# 5         _AAAAAAALQAK_                  160629AEL160624PMRSAM00092_18A1
# 6         _AAAAAAALQAK_                       160623AEL160624PMRSAM00092
# 7         _AAAAAAALQAK_                 160623AEL160624PMRSAM00092_NC126
# 8         _AAAAAAALQAK_                 160623AEL160624PMRSAM00092_NC126
# 9         _AAAAAAALQAK_                   161018A_NC_set#38D_untergeted2
# 10        _AAAAAAALQAK_                    161018A_NC_set#38D_untergeted
# 11        _AAAAAAALQAK_                    161018A_NC_set#38C_untergeted
# 12        _AAAAAAALQAK_                    161018A_NC_set#38B_untergeted
# 13        _AAAAAAALQAK_                    161018A_NC_set#38A_untergeted
# 14        _AAAAAAALQAK_                      160913A_NC_set#32D_250ms_N3
# 15        _AAAAAAALQAK_                      160913A_NC_set#32D_250ms_N3
# 16        _AAAAAAALQAK_                      160913A_NC_set#32C_250ms_N3
# 17        _AAAAAAALQAK_                      160913A_NC_set#32C_250ms_N3
# 18        _AAAAAAALQAK_                      160913A_NC_set#32B_150ms_N3
# 19        _AAAAAAALQAK_                      160913A_NC_set#32B_150ms_N3
# 20        _AAAAAAALQAK_  160902A_NC_set#30G_180min_200NL_60C_N3_250mLC1B
# 21        _AAAAAAALQAK_  160902A_NC_set#30E_180min_200NL_60C_N3_250mLC1B
# 22        _AAAAAAALQAK_  160902A_NC_set#30E_180min_200NL_60C_N3_250mLC1B
# 23        _AAAAAAALQAK_  160902A_NC_set#30D_180min_200NL_60C_N3_250mLC1B
# 24        _AAAAAAALQAK_  160902A_NC_set#30D_180min_200NL_60C_N3_250mLC1B
# 25        _AAAAAAALQAK_  160902A_NC_set#30C_180min_200NL_60C_N3_250mLC1B
# 26        _AAAAAAALQAK_  160902A_NC_set#30C_180min_200NL_60C_N3_250mLC1B
# 27        _AAAAAAALQAK_  160902A_NC_set#30B_180min_200NL_60C_N3_250mLC1B
# 28        _AAAAAAALQAK_  160902A_NC_set#30A_180min_200NL_60C_N3_250mLC1B
# 29        _AAAAAAALQAK_    160822A_NC_set#28A_180min_200NL_60C+N=3_250ms
# ...                 ...                                              ...
# 269445   _YYVTIIDAPGHR_    160822A_NC_set#19B_180min_200NL_60C+N=3_500ms
# 269446   _YYVTIIDAPGHR_                  161102AMR_NC_set#40A_untargeted
# 269447   _YYVTIIDAPGHR_              160818A_NC_set#26D_180min_200NL_60C
# 269448   _YYVTIIDAPGHR_                   160810A_NC_set24C_180min_100NL
# 269449   _YYVTIIDAPGHR_    160822A_NC_set#19A_180min_200NL_60C+N=3_500ms
# 269450   _YYVTIIDAPGHR_    160829A_NC_set#29C_180min_200NL_60C+N=3_250ms
# 269451   _YYVTIIDAPGHR_                    161018A_NC_set#38A_exclusion1
# 269452   _YYVTIIDAPGHR_                     161022A_NC_set#39A_untargted
# 269453   _YYVTIIDAPGHR_                  161102AMR_NC_set#40C_untargeted
# 269454   _YYVTIIDAPGHR_                  161102AMR_NC_set#40C_untargeted
# 269455   _YYVTIIDAPGHR_                  160629AEL160624PMRSAM00092_18B2
# 269456   _YYVTIIDAPGHR_  161006A_NC_set#37D_250ms_N3_LC2_exclusionNew37B
# 269457   _YYVTIIDAPGHR_    160822A_NC_set#28B_180min_200NL_60C+N=3_250ms
# 269458   _YYVTIIDAPGHR_  160902A_NC_set#30I_180min_200NL_60C_N3_250mLC1B
# 269459   _YYVTIIDAPGHR_    160829A_NC_set#29A_180min_200NL_60C+N=3_250ms
# 269460   _YYVTIIDAPGHR_                  161102AMR_NC_set#40D_untargeted
# 269461   _YYVTIIDAPGHR_                  161102AMR_NC_set#40D_untargeted
# 269462   _YYVTIIDAPGHR_                  161102AMR_NC_set#40B_untargeted
# 269463   _YYVTIIDAPGHR_              160728A_NC_set22A_180min_50ID_100NL
# 269464   _YYVTIIDAPGHR_              160728A_NC_set22A_180min_50ID_100NL
# 269465     _YYYDGDMICK_              160818A_NC_set#26C_180min_200NL_60C
# 269466     _YYYDGDMICK_                    161018A_NC_set#38B_untergeted
# 269467     _YYYDGDMICK_                    161018A_NC_set#38A_untergeted
# 269468     _YYYDGDMICK_                    161018A_NC_set#38A_untergeted
# 269469     _YYYDGDMICK_                  161102AMR_NC_set#40A_untargeted
# 269470     _YYYDGDMICK_    160822A_NC_set#28B_180min_200NL_60C+N=3_250ms
# 269471     _YYYDGDMICK_                  161102AMR_NC_set#40B_untargeted
# 269472  _YYYDGKDYIEFNK_  160902A_NC_set#30H_180min_200NL_60C_N3_250mLC1B
# 269473  _YYYDGKDYIEFNK_   1608329A_NC_set#29B_180min_200NL_60C+N=3_250ms
# 269474  _YYYDGKDYIEFNK_    160829A_NC_set#29C_180min_200NL_60C+N=3_250ms
#
#         retention_time           pep  exclude  exp_id  peptide_id
# 0               96.072  1.248000e-03    False       2           3
# 1              104.090  2.812700e-10    False       3           3
# 2              104.100  2.779600e-04    False       3           3
# 3               77.767  4.637300e-10    False       8           3
# 4               73.488  4.637300e-10    False       9           3
# 5               72.872  1.391700e-08    False      10           3
# 6               60.512  6.971200e-12    False      11           3
# 7               61.643  1.391700e-08    False      12           3
# 8               61.643  8.870900e-02    False      12           3
# 9              103.760  3.220800e-09    False      13           3
# 10             103.920  3.345400e-09    False      14           3
# 11             103.240  2.774700e-09    False      15           3
# 12             103.440  1.016300e-05    False      16           3
# 13             103.000  1.921800e-03    False      17           3
# 14             109.580  4.637300e-10    False      18           3
# 15             109.570  1.135500e-03    False      18           3
# 16             109.090  5.746700e-15    False      19           3
# 17             109.260  1.135500e-03    False      19           3
# 18             109.270  6.971200e-12    False      20           3
# 19             109.280  1.135500e-03    False      20           3
# 20             109.250  2.759300e-02    False      21           3
# 21             109.700  2.774700e-09    False      22           3
# 22             109.700  2.126900e-02    False      22           3
# 23             109.710  2.116500e-10    False      23           3
# 24             109.710  7.016700e-03    False      23           3
# 25             109.000  2.774700e-09    False      24           3
# 26             109.130  4.309500e-02    False      24           3
# 27             109.870  1.016300e-05    False      25           3
# 28             111.190  1.308300e-09    False      26           3
# 29              98.797  7.509200e-06    False      27           3
# ...                ...           ...      ...     ...         ...
# 269445         123.940  8.356600e-21    False      72      502711
# 269446         114.380  1.770200e-14    False      73      502711
# 269447         121.990  1.071100e-20    False      77      502711
# 269448         159.130  6.825100e-15    False      78      502711
# 269449         123.340  7.943000e-17    False      81      502711
# 269450         114.060  6.499000e-15    False      82      502711
# 269451         120.520  4.025400e-01    False      84      502711
# 269452         119.620  7.943000e-17    False      89      502711
# 269453         111.970  4.888600e-15    False      90      502711
# 269454         111.980  5.654700e-15    False      90      502711
# 269455          90.228  4.413100e-06    False      91      502711
# 269456         114.940  5.721300e-15    False      92      502711
# 269457         115.800  1.590200e-10    False      98      502711
# 269458         124.960  2.307700e-11    False     101      502711
# 269459         114.070  2.307700e-11    False     104      502711
# 269460         110.540  2.088300e-14    False     106      502711
# 269461         110.540  1.098100e-09    False     106      502711
# 269462         107.110  4.314000e-22    False     109      502711
# 269463         128.230  1.325200e-01    False     111      502711
# 269464         128.250  1.047000e-01    False     111      502711
# 269465          70.138  1.822200e-01    False       3      502731
# 269466          72.642  1.822200e-01    False      16      502731
# 269467          72.571  1.822200e-01    False      17      502731
# 269468          77.466  1.822200e-01    False      17      502731
# 269469          73.412  1.822200e-01    False      73      502731
# 269470          66.576  1.822200e-01    False      98      502731
# 269471          64.497  1.822200e-01    False     109      502731
# 269472         141.750  4.319700e-01    False       1      502733
# 269473         129.350  3.373700e-07    False       2      502733
# 269474         129.450  2.102400e-04    False      82      502733
#
# [269475 rows x 7 columns]

# %%
print(len(df["sequence"].unique()))
print(df["peptide_id"].max())
print(len(df["exp_id"].unique()))
# Out:
# 502762
# 502761
# 112

# %%
# refactorize peptide id into stan_peptide_id, 
# to preserve continuity when feeding data into STAN
dff["stan_peptide_id"] = dff["sequence"].map({ind: val for val, ind in enumerate(dff["sequence"].unique())})
exp_names = dff["raw_file"].unique()
num_experiments = len(exp_names)
num_observations = dff.shape[0]
num_peptides = dff["stan_peptide_id"].max() + 1
retention_times = dff["retention_time"]
peptide_id = dff["peptide_id"]
stan_peptide_id = dff["stan_peptide_id"]
exp_id = dff["exp_id"]
pep_exp_all = dff["stan_peptide_id"].map(str) + " - " + dff["exp_id"].map(str)
pep_exp_pairs = pep_exp_all.unique()
num_pep_exp_pairs = len(pep_exp_pairs)

muij_map = pep_exp_all.map({ind: val for val, ind in enumerate(pep_exp_pairs)})
splt = pd.Series(pep_exp_pairs).str.split(" - ")
muij_to_pep = splt.str.get(0).map(int)
muij_to_exp = splt.str.get(1).map(int)
print(str(num_pep_exp_pairs) + " peptide-experiment pairs.")

pep = dff["pep"]
pep = pep + np.finfo(float).eps
# Out:
# 242761 peptide-experiment pairs.

# %%
plt.hist(pep, bins=30)
plt.show()

# %%
stan_data = {
    "num_experiments": num_experiments,
    "num_peptides": num_peptides,
    "num_pep_exp_pairs": num_pep_exp_pairs,
    "num_total_observations": num_observations,
    "muij_map": muij_map+1,
    "muij_to_pep": (muij_to_pep+1).tolist(),
    "muij_to_exp": (muij_to_exp+1).tolist(),
    "experiment_id": (exp_id+1).tolist(),
    "peptide_id": (stan_peptide_id+1).tolist(),
    "retention_times": retention_times.tolist(),
    "mean_log_rt": np.mean(np.log(retention_times)),
    "sd_log_rt": np.std(np.log(retention_times)),
    "pep": pep.tolist(),
    "max_retention_time": retention_times.max()
}

# %%
filter_pep = 0.5
rt_distortion = 5.0
mu_min = 1.0

def get_mu(x):
    weights = ((1 - x["pep"].values) - (1 - filter_pep)) / filter_pep
    return np.sum(x["retention_time"].values * weights) / np.sum(weights)

#def get_mu(x):
#    return np.sum(x["retention_time"].values) / len(x["retention_time"].values)

mu_init = dff.groupby("stan_peptide_id")[["pep", "retention_time"]].apply(get_mu).values + np.random.normal(0, rt_distortion, num_peptides)

# negative or very low retention times not allowed. floor at 5 minutes
mu_init[mu_init <= mu_min] = mu_min
# canonical retention time shouldn't be bigger than largest real RT
mu_max = retention_times.max()
mu_init[mu_init > mu_max] = mu_max

#np.savetxt("muinit.txt", mu_init)

# %%
plt.hist(mu_init, bins=30)
plt.show()

# %%
# take retention times and distort by +- 10 mins
rt_distorted = retention_times + np.random.normal(0, rt_distortion, len(retention_times))
# make sure distorted retention times stay within bounds of real ones
rt_distorted[rt_distorted > retention_times.max()] = retention_times.max()
rt_distorted[rt_distorted < retention_times.min()] = retention_times.min()

plt.subplot(121)
plt.hist(rt_distorted, bins=30, color='b')
plt.subplot(122)
plt.hist(retention_times, bins=30, color='r')
plt.show()

plt.plot(retention_times, rt_distorted, '.k', alpha=0.1)
plt.plot([0, 300], [0, 300], color='red')
plt.show()

plt.plot(mu_init[stan_peptide_id], rt_distorted, '.k', alpha=0.05)
plt.plot([0, 300], [0, 300], color='red')
plt.show()

# %%
e = 100
mus = mu_init[stan_peptide_id[exp_id==e]]
rts = rt_distorted[exp_id==e]
peps = pep[exp_id==e]

plt.plot(mus, rts, '.k', alpha=0.1)
plt.plot([0, 300], [beta_init[0][0], beta_init[0][0] + (beta_init[1][0] * 300)], '-r')
plt.show()

reg.fit(mus.reshape(-1, 1), rts, 1-peps)
beta0 = reg.intercept_
beta1 = reg.coef_[0]

mu_pred = (rts - beta0) / beta1

plt.plot(mu_pred, rts, '.b', alpha=0.1)
plt.plot([0, 300], [beta0, beta0+(beta1 * 300)], '-r')
plt.show()

# %%
# initialize priors for the segmented linear regression
# first element of vector is beta_0, or the intercept
# second element is beta_1 and beta_2, the slopes of the two segments
beta_init = np.array((np.repeat(10, num_experiments), np.repeat(1, num_experiments)), dtype=float)

mu_pred = np.zeros(num_peptides)
# temporary data frame to quickly map over in the loop
dft = pd.DataFrame(dict(stan_peptide_id=stan_peptide_id, exp_id=exp_id, pep=pep, retention_time=rt_distorted))

reg = linear_model.LinearRegression()
prior_iters=15

for i in range(0, prior_iters):
    # for each experiment, fit a simple linear regression
    # between the distorted RTs and the initial canonical retention times
    for j, e in enumerate(np.sort(exp_id.unique())):
        #print(e)
        idx = (exp_id == e)
        rt_cur = rt_distorted[idx]
        mu_cur = mu_init[stan_peptide_id[idx]]
        pep_cur = pep[idx]

        #m, c = np.polyfit(mu_cur, rt_cur, 1, w=(1 - pep_cur))
        #beta_init[(0,1), j] = [c, m]
        
        reg.fit(mu_cur.reshape(-1, 1), rt_cur, 1 - pep_cur)
        beta_init[0, j] = reg.intercept_
        beta_init[1, j] = reg.coef_[0]

    # calculate new set of canonical RTs based on linear regression params
    mu_pred = (rt_distorted - beta_init[0][exp_id]) / beta_init[1][exp_id] 
    # make sure new canonical RTs are within same range as distorted RTs
    mu_pred[mu_pred <= 0] = rt_distorted.min()
    mu_pred[mu_pred >= rt_distorted.max()] = rt_distorted.max()
    
    #print(dft["retention_time"].head())
    dft["retention_time"] = np.copy(mu_pred)
    print(mu_pred.head())
    #print(dft["retention_time"].head())

    mu_prev = mu_init

    # new set of priors for canonical RTs based on weighted combination of
    # this set of predicted canonical RTs
    mu_init = dft.groupby("stan_peptide_id")[["pep", "retention_time"]].apply(get_mu).values

    print("Iter " + str(i + 1) + " | Avg. canonical RT shift: " + "{:.5f}".format(pow(np.sum(mu_prev - mu_init), 2) / len(mu_init)))
# Out:
# 0    103.342210
# 1    103.822024
# 2    101.396746
# 3     88.299640
# 4     84.615646
# Name: retention_time, dtype: float64
# Iter 1 | Avg. canonical RT shift: 1430.41643
# 0    102.843924
# 1    102.885879
# 2    100.498980
# 3     92.552346
# 4     92.524662
# Name: retention_time, dtype: float64
# Iter 2 | Avg. canonical RT shift: 225.94568
# 0    102.440064
# 1    102.565502
# 2    100.190001
# 3     93.681785
# 4     94.650785
# Name: retention_time, dtype: float64
# Iter 3 | Avg. canonical RT shift: 1.84065
# 0    102.269654
# 1    102.459391
# 2    100.086777
# 3     93.944673
# 4     95.151214
# Name: retention_time, dtype: float64
# Iter 4 | Avg. canonical RT shift: 1.75030
# 0    102.199070
# 1    102.415911
# 2    100.043287
# 3     93.991091
# 4     95.254226
# Name: retention_time, dtype: float64
# Iter 5 | Avg. canonical RT shift: 2.80110
